# %%
name=input("enter your name:  ")
print(name)
# Out:
# enter your name:   Saksham
# Saksham

# %%
print(f"hi {name}")
# Out:
# hi Saksham

# %%
num1= input("enter num1")
num2= input("enter num2")
total=num1+num2
total2= int(num1) +int(num2)
print(total)   # output 34324  b/c it take input as a string whether we put integer tuple or any other thing
print(total2)  # so we have to convert it into a int to get integer value
# Out:
# enter num1 343
# enter num2 24
# 34324
# 367

# %%
list1=[234,435,3245,23452,345]
list2=input("Enter your list").split(",")  #if we put list inside this then it is treated as string to covert it first we have split it  we can't convert it using int method
print(list2)
# Out:
# Enter your list 24 ,2345,2345,2345,234
# ['24 ', '2345', '2345', '2345', '234']

# %%
candidate=input("enter your name")
role=input("enter your role name or job you apply")
joining_date=input("enter your joining date")
package= int(input("enter your package"))

print(f"""

Dear {candidate},

Subject: Offer of Employment for the position of {role}

We are delighted to extend this formal offer of employment to you for the
position of {role} at our organization. Based on your qualifications and the
skills you demonstrated during the recruitment process, we are confident that
you will be a valuable addition to our team.

As discussed, your expected date of joining is {joining_date}. Your total
compensation package will be {package}, which includes all salary components as
per the company’s policy. Further details regarding your compensation will be
provided in your employment contract.

We expect you to bring your best efforts to help the company achieve its goals,
and we are committed to supporting your professional growth during your time
with us.

Please confirm your acceptance of this offer by sending an email to
rkt@gmail.com at your earliest convenience. Should you have any queries
regarding this offer, feel free to reach out to us.

We look forward to having you onboard and are excited about the great things we
can accomplish together.

Sincerely,

Sunil Kumar

HR Manager
""")
# Out:
# enter your name Saksham Taletia
# enter your role name or job you apply Data science
# enter your joining date 1398345
# enter your package 98238475034
# Dear Saksham Taletia,
#
# Subject: Offer of Employment for the position of Data science
#
# We are delighted to extend this formal offer of employment to you for the
# position of Data science at our organization. Based on your qualifications and the
# skills you demonstrated during the recruitment process, we are confident that
# you will be a valuable addition to our team.
#
# As discussed, your expected date of joining is 1398345. Your total
# compensation package will be 98238475034, which includes all salary components as
# per the company’s policy. Further details regarding your compensation will be
# provided in your employment contract.
#
# We expect you to bring your best efforts to help the company achieve its goals,
# and we are committed to supporting your professional growth during your time
# with us.
#
# ...
