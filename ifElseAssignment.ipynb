# %% [markdown]
#  # Q1. Write a program to calculate the electricity bill
# using only if statement? (accept number of unit from user)
# according to the following criteria:
#
# Unit Price
# First 100 units no charge
# Next 100 units Rs 5 per unit
# After 200 units Rs 10 per unit
# (For example, if input unit is 350 than total bill amount is Rs2000). Lets explain...
# For first 100 no charges
# Now you have 250 unit remaining
# 100-200 you need to pay – 100*5 = 500
# Now 200-100 you need to pay 150*10 = 1500
# Total = 500+1500 = 2000

# %%
units= int(input("Enter your Units"))
bill=0
if units >200:
    bill = bill+(units-200)*10
    units=200
if units>100:
    bill=bill+(units-100)*5

print(f"your billl is Rs {bill}")
# Out:
# Enter your Units 300
# your billl is Rs 1500

# %% [markdown]
# # Q2. Write a program to accept percentage from the user and display
# the grade according to the following criteria:
#
# Marks Grade
# > 90 A
# > 80 and <= 90 B
# >= 60 and <= 80 C
# below 60 D

# %%
percentage =int(input("Enter your percenterage : "))
if percentage >90:
    print(" Your Grade is A")
elif percentage>80 and percentage <=90:
    print("Your Grade is B")
elif percentage >=60 and percentage <=80 : 
    print("Your Grade is C")
elif percentage < 60 :
    print("your Grade is D")
else : 
    print("Enter valid number")
# Out:
# Enter your percenterage :  55
# your Grade is D

# %% [markdown]
# # Q3. Accept the age of 4 people and display the youngest one?

# %%
a = int(input("Enter Your age : "))
b = int(input("Enter Your age : "))
c = int(input("Enter Your age : "))
d = int(input("Enter Your age : "))

youngest = a

if b< youngest:
    print("b is youngest")
if c<youngest:
    print("c is youngest")
if d<youngest:
    print("d is youngest")

print(f"youngest is {youngest}")
# Out:
# Enter Your age :  5
# Enter Your age :  2
# Enter Your age :  6
# Enter Your age :  7
# b is youngest
# youngest is 5

# %% [markdown]
#  # Q4. A company decided to give bonus to employee
# according to following criteria:
#
# Time period of Service Bonus
#
# More than 10 years 10%
#
# >=6 and <=10 8%
#
# Less than 6 years 5%
#
# Ask user for their salary and years of service and print the
# net bonus amount?

# %%
salary= float(input("Enter your Salary : "))
year_of_exp=int(input("Enter your Experience"))

if year_of_exp>10:
    salary=salary+salary*.10
    print(salary)
elif year_of_exp >=6 and year_of_exp<=10:
    salary=salary+salary*.08
    print(salary)
elif year_of_exp <6:    
    salary=salary+salary*.05
    print(salary)
# Out:
# Enter your Salary :  1000
# Enter your Experience 2
# 1050.0

# %% [markdown]
# # Q5. Accept three numbers from the user and
# display the second largest number?

# %%
a= int(input("Enter your number"))
b= int(input("Enter your number"))
c= int(input("Enter your number"))

if(a>b and a<c) or (a>c and a<b):
    print("a is second smallest number")
elif (b>a and b<c) or (b<a and b>c):
    print("b is second smallest number")
else:
    print("c is second smallest number")
# Out:
# Enter your number 1
# Enter your number 2
# Enter your number 3
# b is second smallest number

# %% [markdown]
#   # Q6. Accept the marked price from the user and calculate
# the Net amount as (Marked Price – Discount) to pay
# according to following criteria:
#
# Marked Price Discount
# >10000 20%
# >7000 and <=10000 15%
# <=7000 10%

# %%
marked_price = int(input("Enter the Price : "))
if marked_price>10000:
    marked_price= marked_price- marked_price*.20
    print(marked_price)
elif marked_price >7000 and marked_price<=10000 :
    marked_price= marked_price- marked_price*.15
    print(marked_price)
elif marked_price <=7000:
    marked_price= marked_price- marked_price*.10
    print(marked_price)
# Out:
# Enter the Price :  10000
# 8500.0

# %% [markdown]
# # Q7. Accept the marks of English, Math and Science,
# Social Studies Subject and display the stream allotted
# according to following:
#
# All Subjects more than 80 marks — Science Stream
#
# English >80 and Math, Science above 50 — Commerce Stream
#
# English > 80 and social studies > 80 — Humanities

# %%
math_marks= int(input("Enter your math marks"))
english_marks= int(input("Enter your english marks"))
science_marks= int(input("Enter your science marks"))
social_marks= int(input("Enter your social studies marks"))

if math_marks >80 and english_marks>80 and science_marks >80 and social_marks >80 :
    print(" You get Sciene Stream")
elif math_marks>80 and english_marks>80 and science_marks>50:
    print("you get Commerce Stream")
elif english_marks>80 and social_marks>80 :
    print("you get HUmanities")
else :
    print( "you are fail")
# Out:
# Enter your math marks 84
# Enter your english marks 90
# Enter your science marks 90
# Enter your social studies marks 98
#  You get Sciene Stream

# %% [markdown]
#  # Q8. Write a program to display "Hello" if a number entered by user is a multiple of five, otherwise print "Bye"?

# %%
number= int(input("Enter the number"))
if number%5==0:
    print("hello")
else :
    print("bye")
# Out:
# Enter the number 34
# bye

# %% [markdown]
# # Q9. Write a program to check whether the last digit of a number
# (entered by user) is divisible by 3 or not?

# %%
number = int(input("Enter your number "))
reminder = number%3
if reminder%3==0:
    print("Yes last digit of a number is divisable by 3")
else : 
    print("No it is not divisable")
# Out:
# Enter your number  1234
# No it is not divisable

# %% [markdown]
# # Q10. Write a program to check whether a number entered is three-digit number or not?

# %%
number = input("Enter the number ")
if len(numbe==3:
    print("yes it length is 3")
else : 
    print("No it length is not 3")
# Out:
# Enter the number  234
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 number = input("Enter the number ")
# ----> 2 if number.len==3:
#       3     print("yes it length is 3")
#       4 else :
#
# AttributeError: 'str' object has no attribute 'len'
