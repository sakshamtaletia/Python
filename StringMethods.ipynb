# %% [markdown]
# # string.capitalize()

# %%
string="python"
string.capitalize()  # this convert first letter capital
# Out:
# 'Python'

# %% [markdown]
# # string.casefold()

# %%
string= "MethodS IN PytHON"
string.casefold()  # it convert all uppercase alphabet to lowercase
# Out:
# 'methods in python'

# %% [markdown]
# # string.center()

# %%
string = "Saksham"
string.center(9,"-")  # it takes two argument first decide the length of a string 2nd is optional or we can give any symbol we want execpt space
# Out:
# '-Saksham-'

# %% [markdown]
# # string.count()

# %%
string="python"
string.count("y") # it count a particular alphat inside a string
# Out:
# 1

# %% [markdown]
# # string.encode()

# %%
string="hell0 " 
string.encode()
# Out:
# b'hello S#al '

# %% [markdown]
# # string.endswith()

# %%
string ="python with Saksham Taletia"
string.endswith("a")   # it tell whether a particular string ends with particular letter or alphbat
# Out:
# True

# %% [markdown]
# # string.expandtabs()

# %%
string="h\te\tllo"
print(string.expandtabs(3)) # using this we can expand the size to tab which we give using \t
string.expandtabs(5)
# Out:
# h  e  llo
# 'h    e    llo'

# %% [markdown]
# # string.find()

# %%
string= "python"
string.find("o")  # it return index number which we want to find
# Out:
# 4

# %% [markdown]
# # string.format()

# %%
string ="my name is {fname}"
string.format(fname="Saksham")
# Out:
# 'my name is Saksham'

# %% [markdown]
# # string.format_map()

# %%
str1 = {"name":"saksham","age":21}
str2="i am {name} and my age is {age}"
str2.format_map(str1)   # it format str1 values into str2
# Out:
# 'i am saksham and my age is 21'

# %% [markdown]
# # string.index()

# %%
string= "hello:"
string.index(":")  # it return index number of particular charcter
# Out:
# 5

# %% [markdown]
# # string.isalnum()

# %%
string="saksham9840592330"
string.isalnum()  # it check wheather txt is in alphanumric form or not and return boolean value
# Out:
# True

# %% [markdown]
# # string.isalpha()

# %%
string="python"
print(string.isalpha())
print("str1".isalpha()) # Check if all the characters in the text are letters
# Out:
# True
# False

# %% [markdown]
# # string.isascii()

# %%
string="hello %"
string.isascii() # Check if all the characters in the text are ascii characters:
# Out:
# True

# %% [markdown]
# # string.isdecimal()

# %%
string="2345"
string.isdecimal() # Check if all the characters in a string are decimals (0-9)
# Out:
# True

# %% [markdown]
# # string.isdigit()

# %%
string="3452d3"
string.isdigit() # 	Returns True if all characters in the string are digits
# Out:
# False

# %% [markdown]
# # string.isidentifier()

# %%
a = "MyFolder"
b = "pythono002"
c = "2bring"
d = "my demo"

print(a.isidentifier())
print(b.isidentifier())
print(c.isidentifier())
print(d.isidentifier()) #A string is considered a valid identifier if it only contains alphanumeric letters (a-z) and (0-9), or underscores (_). A valid identifier cannot start with a number, or contain any spaces.
# Out:
# True
# True
# False
# False

# %% [markdown]
# # string.islower()

# %%
string = "hello"
str2 = "Hello"
print(string.islower())
print(str2.islower()) #Check if all the characters in the text are in lower case:
# Out:
# True
# False

# %% [markdown]
# # string.isnumeric()

# %%
str1="3q4534"
str2="34523"
str3="-1345"
print(str1.isnumeric())
print(str2.isnumeric())    #Check if all the characters in the text are numeric
print(str3.isnumeric())
# Out:
# False
# True
# False

# %% [markdown]
# # string.isprintable()

# %%
string="hello python"
string.isprintable() # some non printable charchter \n \t etc
# Out:
# True

# %% [markdown]
# # string.isspace()

# %%
string="      "
string.isspace() #  returns True if all the characters in a string are whitespaces
# Out:
# True

# %% [markdown]
# # string.istitle()

# %%
str1 = "hey Saksham"
str1.istitle() #returns True if string start with a upper case letter, AND the rest of the word are lower case letters
# Out:
# False

# %% [markdown]
# # string.isupper()

# %%
str1= "HELLO"
str1.isupper()  #returns True if every  string letter in upper case, otherwise False.
# Out:
# True

# %% [markdown]
# # string.join()

# %%
s= ("saksham" ,"taletia")
" ".join(s)  #Join all items in a tuple into a string
# Out:
# 'saksham taletia'

# %% [markdown]
# # string.ljust()

# %%
string = "python"
string.ljust(28,"0")  # it increase length of string as 1st argument and add 2nd argument as a remaing spce and it add at right side
# Out:
# 'python0000000000000000000000'

# %% [markdown]
# # string.lower()

# %%
string="Python with Saksham"
string.lower() # covert whole string in lowercase
# Out:
# 'python with saksham'

# %% [markdown]
# # string.lstrip()

# %%
string="                     hello           "
string.lstrip()   # it trim left side space
# Out:
# 'hello           '

# %% [markdown]
# # string.maketrans()

# %%
str1 = "Hi Sam!"

x = "mSa"
y = "eJo"
print(str1.maketrans(x,y))  # this give ascci values
str2 =str1.maketrans(x,y)
print(str1.translate(str2)) # maketrans() is used to create a translation table that maps characters to other characters.It is used with the translate() method to replace characters in a string.
# Out:
# {109: 101, 83: 74, 97: 111}
# Hi Joe!

# %% [markdown]
# # string.partition()

# %%
str1 = "python is used for data science and data anasyis"
str1.partition("and") # splits the string into a tuple containing three elements.
# Out:
# ('python is used for data science ', 'and', ' data anasyis')

# %% [markdown]
# # string.removeprefix()

# %%
str1 = "unhappy"
str1.removeprefix("un")  # it remove prefix
# Out:
# 'happy'

# %% [markdown]
# # string.removesuffix()

# %%
str2= "hellosg"
str2.removesuffix("sg")
# Out:
# 'hello'

# %% [markdown]
# # string.replace()

# %%
str1="hello"
str1.replace("hello","python")
# Out:
# 'python'

# %% [markdown]
# # string.rfind()

# %%
str1= "ehllo hello ptython"
str1.rfind('o')  #finds the last occurrence of the specified value or we  SAY IT START FINDING FROM BACKSIDE
# Out:
# 17

# %% [markdown]
# # string.rindex()

# %%
str1= "saksham"
str1.rindex("a") # it is same as rfind
# Out:
# 5

# %% [markdown]
# # string.rjust()

# %%
str1="python"
str1.rjust(23,"-") # it same as ljust but it add things at left side
# Out:
# '-----------------python'

# %% [markdown]
# # string.rpartition()

# %%
string="i am saksham and i am software enginner"
string.rpartition("and")
# Out:
# ('i am saksham ', 'and', ' i am software enginner')

# %% [markdown]
# # string.rsplit()

# %%
str1="saksham,taletia,python"
str1.rsplit()  #Split a string into a list,
# Out:
# ['saksham,taletia,python']

# %% [markdown]
# # string.splitlines()

# %%
string='saksham \n taletia \n python'
string.splitlines()  # splits line into a list
# Out:
# ['saksham ', ' taletia ', ' python']

# %% [markdown]
# # string.rstrip()

# %%
str1="      hello       "
str1.rstrip(" ")  # remove thing from right of the string
# Out:
# '      hello'

# %% [markdown]
# # string.startswith()

# %%
string= "startwith"

string.startswith("s")  # CHECK whether a strign start with this or not
# Out:
# True

# %% [markdown]
# # string.strip()

# %%
string= "          hello           "
string.strip(" ") # trim string from both side
# Out:
# 'hello'

# %% [markdown]
# # string.swapcase()

# %%
string='SakshaM'
string.swapcase() # swap cases of alphabets
# Out:
# 'sAKSHAm'

# %% [markdown]
# # string.title()

# %%
string= " my first python program"
string.title() # convert every first letter of stirng into uppercase
# Out:
# ' My First Python Program'

# %% [markdown]
# # string.upper()

# %%
string = "saksham"
string.upper() # coonveert into upper case
# Out:
# 'SAKSHAM'

# %% [markdown]
# # string.zfill()

# %%
string="hello"
string.zfill(23)  #adds zeros (0) at the beginning of the string, until it reaches the specified length.
# Out:
# '000000000000000000hello'
